# %% [markdown]
# # read file and make it in one data fram

# %%
import numpy as np
import pandas as pd 
import os

# %%
files = [file for file in os.listdir('./Sales_Data')]
data = pd.DataFrame()
for file in files:
    df =pd.read_csv("./Sales_Data/"+file)
    data = pd.concat([data, df])
    data.to_csv(index=False)

# %%
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %% [markdown]
# # Delete Rows don't have a value

# %%
data[data['Price Each'].isna()]
# Out:
#       Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1          NaN     NaN              NaN        NaN        NaN              NaN
# 356        NaN     NaN              NaN        NaN        NaN              NaN
# 735        NaN     NaN              NaN        NaN        NaN              NaN
# 1433       NaN     NaN              NaN        NaN        NaN              NaN
# 1553       NaN     NaN              NaN        NaN        NaN              NaN
# ...        ...     ...              ...        ...        ...              ...
# 10012      NaN     NaN              NaN        NaN        NaN              NaN
# 10274      NaN     NaN              NaN        NaN        NaN              NaN
# 10878      NaN     NaN              NaN        NaN        NaN              NaN
# 11384      NaN     NaN              NaN        NaN        NaN              NaN
# 11662      NaN     NaN              NaN        NaN        NaN              NaN
#
# [545 rows x 6 columns]

# %%
data = data.dropna()

# %%
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
data.loc[:, 'Price Each'] = pd.to_numeric(data["Price Each"], errors='coerce')

# %%
data[data['Price Each'].isna()]
# Out:
#        Order ID  Product  Quantity Ordered Price Each  Order Date  \
# 519    Order ID  Product  Quantity Ordered        NaN  Order Date
# 1149   Order ID  Product  Quantity Ordered        NaN  Order Date
# 1155   Order ID  Product  Quantity Ordered        NaN  Order Date
# 2878   Order ID  Product  Quantity Ordered        NaN  Order Date
# 2893   Order ID  Product  Quantity Ordered        NaN  Order Date
# ...         ...      ...               ...        ...         ...
# 10000  Order ID  Product  Quantity Ordered        NaN  Order Date
# 10387  Order ID  Product  Quantity Ordered        NaN  Order Date
# 11399  Order ID  Product  Quantity Ordered        NaN  Order Date
# 11468  Order ID  Product  Quantity Ordered        NaN  Order Date
# 11574  Order ID  Product  Quantity Ordered        NaN  Order Date
#
#        Purchase Address
# 519    Purchase Address
# 1149   Purchase Address
# 1155   Purchase Address
# 2878   Purchase Address
# 2893   Purchase Address
# ...

# %%
data=data.dropna()

# %% [markdown]
# # convert order Data to datetime type

# %%
data["Order Date"].dtype
# Out:
# dtype('O')

# %%
data.loc[:, "Order Date"] = pd.to_datetime(data.loc[:, "Order Date"])

# %%
data["Order Date"]
# Out:
# 0       2019-04-19 08:46:00
# 2       2019-04-07 22:30:00
# 3       2019-04-12 14:38:00
# 4       2019-04-12 14:38:00
# 5       2019-04-30 09:27:00
#                 ...
# 11681   2019-09-17 20:56:00
# 11682   2019-09-01 16:00:00
# 11683   2019-09-23 07:39:00
# 11684   2019-09-19 17:30:00
# 11685   2019-09-30 00:18:00
# Name: Order Date, Length: 185950, dtype: datetime64[ns]

# %%
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1      600.0
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1      700.0
# 11683   259355                      iPhone                1      700.0
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#                Order Date                         Purchase Address
# ...

# %% [markdown]
# # Add col month

# %%
data.loc[:, 'month'] = data.loc[:, "Order Date"].dt.month

# %%
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1      600.0
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1      700.0
# 11683   259355                      iPhone                1      700.0
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#                Order Date                         Purchase Address  month
# ...

# %%
data = pd.merge(data, data.groupby('month')['Price Each'].sum(), on='month', suffixes=('', '_MonthlySum'))

# %%
data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1        176559  Bose SoundSport Headphones                1      99.99
# 2        176560                Google Phone                1      600.0
# 3        176560            Wired Headphones                1      11.99
# 4        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 185945   255614  Bose SoundSport Headphones                1      99.99
# 185946   256859       AA Batteries (4-pack)                1       3.84
# 185947   257017      AAA Batteries (4-pack)                3       2.99
# 185948   258243  Bose SoundSport Headphones                1      99.99
# 185949   259228       AA Batteries (4-pack)                1       3.84
#
#                 Order Date                            Purchase Address  month  \
# ...

# %%
data['month'] = data['month'].astype(int)

# %%
data['month'].dtype
# Out:
# dtype('int32')

# %%
data['Quantity Ordered']=data['Quantity Ordered'].astype(int)

# %%
data.groupby('month')[['Quantity Ordered', 'Price Each_MonthlySum']].sum()
# Out:
#        Quantity Ordered Price Each_MonthlySum
# month
# 1                 10903    17590459201.416538
# 2                 13449    26211894522.002674
# 3                 17005    42295172248.008209
# 4                 20558    61557658574.619644
# 5                 18667    51936482903.575653
# 6                 15253     34725695117.94751
# 7                 16072    37626887931.085403
# 8                 13448    26677161568.612747
# 9                 13109    24229693077.891033
# 10                22703    75358883062.095032
# 11                19798    55892695749.645889
# 12                28114   114636970603.509979

# %% [markdown]
# # Add col city

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]
data['city'] = data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")

# %%
data
# Out:
#        Order ID                     Product  Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                 2      11.95
# 1        176559  Bose SoundSport Headphones                 1      99.99
# 2        176560                Google Phone                 1      600.0
# 3        176560            Wired Headphones                 1      11.99
# 4        176561            Wired Headphones                 1      11.99
# ...         ...                         ...               ...        ...
# 185945   255614  Bose SoundSport Headphones                 1      99.99
# 185946   256859       AA Batteries (4-pack)                 1       3.84
# 185947   257017      AAA Batteries (4-pack)                 3       2.99
# 185948   258243  Bose SoundSport Headphones                 1      99.99
# 185949   259228       AA Batteries (4-pack)                 1       3.84
#
#                 Order Date                            Purchase Address  month  \
# ...

# %% [markdown]
# # find city with the highest sales

# %%
data.groupby('city')[['Quantity Ordered', 'Price Each', 'Price Each_MonthlySum']].sum()
# Out:
#                      Quantity Ordered      Price Each Price Each_MonthlySum
# city
# Atlanta  (GA)                   16602       2779908.2    45505503002.064026
# Austin  (TX)                    11153      1809873.61    30254694736.098495
# Boston  (MA)                    22528  3637409.770001    61012530172.200439
# Dallas  (TX)                    16730      2752627.82    45305185215.604019
# Los Angeles  (CA)               33289  5421435.230002    90504754323.255402
# New York City  (NY)             27932  4635370.830002    76133163397.759064
# Portland  (ME)                   2750       447189.25     7457385358.641485
# Portland  (OR)                  11303      1860558.22    30682517712.188766
# San Francisco  (CA)             50239  8211461.740004   136763525123.915237
# Seattle  (WA)                   16553      2733296.01    45120395518.693916

# %% [markdown]
# ## save data as csv

# %%
path = os.path.join("C:/Users/hp/anaconda3/Scripts/Pandas-Data-Science-Tasks-master/Pandas-Data-Science-Tasks-master/SalesAnalysis/Output/", "data.csv")

# %%
data.to_csv(path, index=False)
